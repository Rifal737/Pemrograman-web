# %% [markdown]
# <a href="https://colab.research.google.com/github/Rifal737/Pemrograman-web/blob/main/Copy_of_P1_Big_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Big Data dengan Dataset Saham Antam**

# %% [markdown]
# **Nama & NIM :**
#
# **1. Arsya Pramudya Kuntadi (24.11.6078)
# 2. Muhamad Rifal (24.11.6082)**
#
#
# **Kelas : IF 03**

# %% [markdown]
# **1. Menambah Library**

# %%
#import Library
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# **2. Mengupload File**

# %% [markdown]
# **dari link gitthub/website**

# %% [markdown]
# **a. Dari Lokal Komputer**

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-02f1be32-6e4b-43f6-8325-a924c6deaf7d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02f1be32-6e4b-43f6-8325-a924c6deaf7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **b. Dari link google collab**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Big Data/ANTM.JK.csv')
df.head(10)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2005-09-29  432.588074  436.787964  407.388763  432.588074  304.904572
# 1  2005-09-30  457.787384  457.787384  432.588074  457.787384  322.666016
# 2  2005-10-03  470.387024  474.586914  440.987854  470.387024  331.546692
# 3  2005-10-04  474.586914  482.986694  466.187164  474.586914  334.506927
# 4  2005-10-05  482.986694  482.986694  466.187164  482.986694  340.427429
# 5  2005-10-06  466.187164  482.986694  461.987274  466.187164  328.586487
# 6  2005-10-07  470.387024  470.387024  457.787384  470.387024  331.546692
# 7  2005-10-10  466.187164  470.387024  457.787384  466.187164  328.586487
# 8  2005-10-11  466.187164  466.187164  461.987274  466.187164  328.586487
# 9  2005-10-12  470.387024  474.586914  466.187164  470.387024  331.546692
#
#         Volume
# ...

# %% [markdown]
# **c. Dari API Kaggle**

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-42e149e6-7fba-4cba-ab66-571e74b8465d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42e149e6-7fba-4cba-ab66-571e74b8465d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d muhardianabasandi/antam-stock-market-by-kitto
# Out:
# Dataset URL: https://www.kaggle.com/datasets/muhardianabasandi/antam-stock-market-by-kitto
# License(s): CC0-1.0
# ...
# 100% 62.8k/62.8k [00:00<00:00, 334kB/s]

# %% [markdown]
# Karena masih dalam bentuk Zip kita unzip dulu

# %%
# !unzip antam-stock-market-by-kitto.zip
# Out:
# Archive:  antam-stock-market-by-kitto.zip
# replace ANTM.JK.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: r
# new name: antam_stock_market.csv
# replace antam_stock_market.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: antam_stock_market.csv

# %%
df = pd.read_csv('antam_stock_market.csv')
df.head(5)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2005-09-29  432.588074  436.787964  407.388763  432.588074  304.904572
# 1  2005-09-30  457.787384  457.787384  432.588074  457.787384  322.666016
# 2  2005-10-03  470.387024  474.586914  440.987854  470.387024  331.546692
# 3  2005-10-04  474.586914  482.986694  466.187164  474.586914  334.506927
# 4  2005-10-05  482.986694  482.986694  466.187164  482.986694  340.427429
#
#         Volume
# 0   76180670.0
# 1  105493978.0
# 2   59712955.0
# 3   56236668.0
# 4   31319315.0

# %% [markdown]
# **d. Dari link Github/website**

# %% [markdown]
# **3. Menampilkan Dataset**

# %%
#membaca file dataset csv
df=pd.read_csv("ANTM.JK.csv",encoding='latin1')
#menampilkan 10 data teratas
df.head(20)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2005-09-29  432.588074  436.787964  407.388763  432.588074  304.904572
# 1   2005-09-30  457.787384  457.787384  432.588074  457.787384  322.666016
# 2   2005-10-03  470.387024  474.586914  440.987854  470.387024  331.546692
# 3   2005-10-04  474.586914  482.986694  466.187164  474.586914  334.506927
# 4   2005-10-05  482.986694  482.986694  466.187164  482.986694  340.427429
# 5   2005-10-06  466.187164  482.986694  461.987274  466.187164  328.586487
# 6   2005-10-07  470.387024  470.387024  457.787384  470.387024  331.546692
# 7   2005-10-10  466.187164  470.387024  457.787384  466.187164  328.586487
# 8   2005-10-11  466.187164  466.187164  461.987274  466.187164  328.586487
# 9   2005-10-12  470.387024  474.586914  466.187164  470.387024  331.546692
# 10  2005-10-13  474.586914  474.586914  470.387024  474.586914  334.506927
# ...

# %% [markdown]
# **4. Menampilkan Struktur Dataset**

# %%
#Melihat struktur Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3808 entries, 0 to 3807
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3808 non-null   object
#  1   Open       3807 non-null   float64
#  2   High       3807 non-null   float64
#  3   Low        3807 non-null   float64
#  4   Close      3807 non-null   float64
#  5   Adj Close  3807 non-null   float64
#  6   Volume     3807 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 208.4+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.shape
# Out:
# (3808, 7)
